# %% [markdown]
# # 03 — Efficiency
# Estimate revision models, martingale diagnostics, and chronological out-of-sample performance.

# %%
from pathlib import Path

import pandas as pd

from pm_efficiency.analysis.efficiency_study import run_efficiency_analysis

panel = pd.read_parquet(Path("..") / "data/processed/efficiency_panel.parquet")
results = run_efficiency_analysis(panel, minimum_training_events=60)
results["martingale_tests"]

# %%
results["oos_performance"]
